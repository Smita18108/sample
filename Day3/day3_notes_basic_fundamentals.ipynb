# %%
# for loop
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# while loop
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# nested for loop
for i in range(2):
    print("Hey")
    for j in range(3):
      print("Hi")
      for x in range(2):
         print("Hello")
# Out:
# Hey
# Hi
# Hello
# Hello
# Hi
# Hello
# Hello
# Hi
# Hello
# Hello
# Hey
# Hi
# Hello
# Hello
# Hi
# Hello
# Hello
# Hi
# Hello
# Hello

# %%
# function definition
def conditional():
    if True:
        for i in range(5):
            print("Hello")
        else:
            print("Not hello")

# %%
# functions in arguments
def work(a,b):
    print(a)
    print(b)

work("hello", "world")
# Out:
# hello
# world

# %%
# python string ko ek ek char print karna
a= "Python"

# %%
# print I like ye vo color

a=["red", "green", "blue"]
for i in range(len(a)): # Corrected the range to use the length of the list
    print("I like", a[i])

# The second loop was also attempting to print with non-printable characters, removing them.
for color in a:
    print("I like ", color)
# Out:
# I like red
# I like green
# I like blue
# I like  red
# I like  green
# I like  blue
